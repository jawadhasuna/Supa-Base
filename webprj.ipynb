# %%
# !nvidia-smi
# Out:
# Sun Jun 21 09:06:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.74                 Driver Version: 591.74         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050      WDDM  |   00000000:04:00.0  On |                  N/A |
# |  0%   44C    P8              8W /  130W |     716MiB /   8192MiB |     11%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             856    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            1104    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            2376    C+G   ...ocal\Programs\Opera\opera.exe      N/A      |
# |    0   N/A  N/A            2664    C+G   ....0.3967.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            7108    C+G   ...mon\Client\v1.6.0\rsAppUI.exe      N/A      |
# |    0   N/A  N/A            8164    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A            8812    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A            9944    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           11616    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           12000    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           12688    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12840    C+G   ...ocal\Programs\Opera\opera.exe      N/A      |
# |    0   N/A  N/A           13604    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           13824    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           13932    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           14196    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           16440    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           18116    C+G   ....0.3967.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           18396    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           22288    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install supabase streamlit
# Out:
# Collecting supabase
#   Downloading supabase-0.7.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting streamlit
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl.metadata (7.4 kB)
# Collecting gotrue<0.6.0,>=0.5.0 (from supabase)
#   Downloading gotrue-0.5.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting httpx<0.24.0,>=0.23.0 (from supabase)
#   Downloading httpx-0.23.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting postgrest-py<0.11.0,>=0.10.2 (from supabase)
#   Downloading postgrest_py-0.10.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting python-semantic-release==7.32.1 (from supabase)
#   Downloading python_semantic_release-7.32.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting realtime<0.0.6,>=0.0.5 (from supabase)
#   Downloading realtime-0.0.5-py3-none-any.whl.metadata (531 bytes)
# Collecting storage3<0.4.0,>=0.3.5 (from supabase)
#   Downloading storage3-0.3.6-py3-none-any.whl.metadata (1.6 kB)
# Collecting supafunc<0.3.0,>=0.2.2 (from supabase)
#   Downloading supafunc-0.2.2-py3-none-any.whl.metadata (521 bytes)
# Collecting click<9,>=7 (from python-semantic-release==7.32.1->supabase)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting click-log<1,>=0.3 (from python-semantic-release==7.32.1->supabase)
#   Downloading click_log-0.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting gitpython<4,>=3.0.8 (from python-semantic-release==7.32.1->supabase)
#   Downloading gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Collecting invoke<2,>=1.4.1 (from python-semantic-release==7.32.1->supabase)
#   Downloading invoke-1.7.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting semver<3,>=2.10 (from python-semantic-release==7.32.1->supabase)
#   Downloading semver-2.13.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting twine<4,>=3 (from python-semantic-release==7.32.1->supabase)
#   Downloading twine-3.8.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2.25 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from python-semantic-release==7.32.1->supabase) (2.31.0)
# Collecting wheel (from python-semantic-release==7.32.1->supabase)
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting python-gitlab<4,>=2 (from python-semantic-release==7.32.1->supabase)
#   Downloading python_gitlab-3.15.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tomlkit~=0.10 (from python-semantic-release==7.32.1->supabase)
#   Downloading tomlkit-0.12.5-py3-none-any.whl.metadata (2.7 kB)
# Collecting dotty-dict<2,>=1.3.0 (from python-semantic-release==7.32.1->supabase)
#   Downloading dotty_dict-1.3.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from python-semantic-release==7.32.1->supabase) (24.0)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.6.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (6.7.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (1.21.6)
# Collecting packaging (from python-semantic-release==7.32.1->supabase)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (1.3.5)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (4.24.4)
# Collecting pyarrow>=4.0 (from streamlit)
#   Downloading pyarrow-12.0.1-cp37-cp37m-win_amd64.whl.metadata (3.1 kB)
# Collecting pympler<2,>=0.9 (from streamlit)
#   Downloading Pympler-1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (2.9.0.post0)
# Collecting rich<14,>=10.11.0 (from streamlit)
#   Downloading rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.0.0 (from streamlit)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting toml<2 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (4.7.1)
# Collecting tzlocal<5,>=1.1 (from streamlit)
#   Downloading tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pydeck<1,>=0.1.dev5 (from streamlit)
#   Downloading pydeck-0.8.1b1-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from streamlit) (6.2)
# Collecting watchdog (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: jinja2 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from click<9,>=7->python-semantic-release==7.32.1->supabase) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.0.8->python-semantic-release==7.32.1->supabase)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting pydantic<2.0.0,>=1.9.1 (from gotrue<0.6.0,>=0.5.0->supabase)
#   Downloading pydantic-1.10.26-py3-none-any.whl.metadata (155 kB)
#      ------------------------------------ 155.1/155.1 kB 544.7 kB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from httpx<0.24.0,>=0.23.0->supabase) (2026.4.22)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx<0.24.0,>=0.23.0->supabase)
#   Downloading httpcore-0.16.3-py3-none-any.whl.metadata (16 kB)
# Collecting rfc3986<2,>=1.3 (from rfc3986[idna2008]<2,>=1.3->httpx<0.24.0,>=0.23.0->supabase)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: sniffio in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from httpx<0.24.0,>=0.23.0->supabase) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from pandas<3,>=0.25->streamlit) (2026.2)
# Collecting deprecation<3.0.0,>=2.1.0 (from postgrest-py<0.11.0,>=0.10.2->supabase)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting strenum<0.5.0,>=0.4.9 (from postgrest-py<0.11.0,>=0.10.2->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from pympler<2,>=0.9->streamlit) (308)
# Requirement already satisfied: six>=1.5 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil<3,>=2->streamlit) (1.17.0)
# Collecting dataclasses<0.7,>=0.6 (from realtime<0.0.6,>=0.0.5->supabase)
#   Downloading dataclasses-0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting websockets<11.0,>=10.3 (from realtime<0.0.6,>=0.0.5->supabase)
#   Downloading websockets-10.4-cp37-cp37m-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.25->python-semantic-release==7.32.1->supabase) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.25->python-semantic-release==7.32.1->supabase) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.25->python-semantic-release==7.32.1->supabase) (2.0.7)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.11.0->streamlit)
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.17.2)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting tzdata (from tzlocal<5,>=1.1->streamlit)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting backports.zoneinfo (from tzlocal<5,>=1.1->streamlit)
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.0.8->python-semantic-release==7.32.1->supabase)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.15,>=0.13 (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->supabase)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->supabase) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.19.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting requests-toolbelt>=0.10.1 (from python-gitlab<4,>=2->python-semantic-release==7.32.1->supabase)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting pkginfo>=1.8.1 (from twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading pkginfo-1.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting readme-renderer>=21.0 (from twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading readme_renderer-37.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tqdm>=4.14 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from twine<4,>=3->python-semantic-release==7.32.1->supabase) (4.67.3)
# Collecting keyring>=15.1 (from twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading keyring-24.1.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: exceptiongroup in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->supabase) (1.3.1)
# Collecting jaraco.classes (from keyring>=15.1->twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting pywin32-ctypes>=0.2.0 (from keyring>=15.1->twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: bleach>=2.1.0 in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.32.1->supabase) (6.0.0)
# Collecting docutils>=0.13.1 (from readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading docutils-0.20.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: webencodings in c:\users\jawad hassan\appdata\local\programs\python\python37\lib\site-packages (from bleach>=2.1.0->readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.32.1->supabase) (0.5.1)
# Collecting more-itertools (from jaraco.classes->keyring>=15.1->twine<4,>=3->python-semantic-release==7.32.1->supabase)
#   Downloading more_itertools-9.1.0-py3-none-any.whl.metadata (32 kB)
# Downloading supabase-0.7.1-py3-none-any.whl (10 kB)
# Downloading python_semantic_release-7.32.1-py3-none-any.whl (54 kB)
#    ---------------------------------------- 54.9/54.9 kB 1.4 MB/s eta 0:00:00
# Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#    ---------------------------------------- 8.9/8.9 MB 5.0 MB/s eta 0:00:00
# Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#    ---------------------------------------- 471.5/471.5 kB 1.8 MB/s eta 0:00:00
# Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ---------------------------------------- 98.2/98.2 kB 806.9 kB/s eta 0:00:00
# Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
#    ---------------------------------------- 212.5/212.5 kB 6.5 MB/s eta 0:00:00
# Downloading gotrue-0.5.4-py3-none-any.whl (24 kB)
# Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#    ---------------------------------------- 71.5/71.5 kB 3.8 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ---------------------------------------- 53.0/53.0 kB 2.9 MB/s eta 0:00:00
# Downloading postgrest_py-0.10.4-py3-none-any.whl (17 kB)
# Downloading pyarrow-12.0.1-cp37-cp37m-win_amd64.whl (21.5 MB)
#    ---------------------------------------- 21.5/21.5 MB 5.5 MB/s eta 0:00:00
# Downloading pydeck-0.8.1b1-py2.py3-none-any.whl (7.0 MB)
#    ---------------------------------------- 7.0/7.0 MB 6.0 MB/s eta 0:00:00
# Downloading Pympler-1.1-py3-none-any.whl (165 kB)
#    ---------------------------------------- 165.8/165.8 kB 5.0 MB/s eta 0:00:00
# Downloading realtime-0.0.5-py3-none-any.whl (8.0 kB)
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
#    ---------------------------------------- 241.6/241.6 kB 1.9 MB/s eta 0:00:00
# Downloading storage3-0.3.6-py3-none-any.whl (12 kB)
# Downloading supafunc-0.2.2-py3-none-any.whl (2.8 kB)
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
#    ---------------------------------------- 82.0/82.0 kB 2.2 MB/s eta 0:00:00
# Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading dotty_dict-1.3.1-py3-none-any.whl (7.0 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 62.8/62.8 kB 3.3 MB/s eta 0:00:00
# Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#    ---------------------------------------- 69.6/69.6 kB 3.7 MB/s eta 0:00:00
# Downloading invoke-1.7.3-py3-none-any.whl (216 kB)
#    ---------------------------------------- 216.4/216.4 kB 6.6 MB/s eta 0:00:00
# Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#    ---------------------------------------- 84.5/84.5 kB 1.6 MB/s eta 0:00:00
# Downloading pydantic-1.10.26-py3-none-any.whl (166 kB)
#    ---------------------------------------- 167.0/167.0 kB 5.1 MB/s eta 0:00:00
# Downloading python_gitlab-3.15.0-py3-none-any.whl (135 kB)
#    ---------------------------------------- 135.9/135.9 kB 3.9 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Downloading tomlkit-0.12.5-py3-none-any.whl (37 kB)
# Downloading twine-3.8.0-py3-none-any.whl (36 kB)
# Downloading websockets-10.4-cp37-cp37m-win_amd64.whl (101 kB)
#    ---------------------------------------- 101.4/101.4 kB 1.4 MB/s eta 0:00:00
# Downloading backports.zoneinfo-0.2.1-cp37-cp37m-win_amd64.whl (38 kB)
# Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#    ---------------------------------------- 349.3/349.3 kB 4.3 MB/s eta 0:00:00
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Downloading keyring-24.1.1-py3-none-any.whl (37 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Downloading readme_renderer-37.3-py3-none-any.whl (14 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 54.5/54.5 kB 2.9 MB/s eta 0:00:00
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#    ---------------------------------------- 572.7/572.7 kB 2.4 MB/s eta 0:00:00
# Downloading pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#    ---------------------------------------- 54.2/54.2 kB 697.9 kB/s eta 0:00:00
# Building wheels for collected packages: validators
#   Building wheel for validators (pyproject.toml): started
#   Building wheel for validators (pyproject.toml): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19585 sha256=f106297e06a48e99d46be4f4c8edfce1337de330c6541dab310bce34875751e7
#   Stored in directory: c:\users\jawad hassan\appdata\local\pip\cache\wheels\5f\55\ab\36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# Installing collected packages: strenum, rfc3986, invoke, dataclasses, wheel, websockets, watchdog, validators, tzdata, toolz, tomlkit, toml, tenacity, smmap, semver, pywin32-ctypes, pympler, pydantic, pyarrow, pkginfo, packaging, more-itertools, mdurl, h11, dotty-dict, docutils, cachetools, blinker, backports.zoneinfo, requests-toolbelt, realtime, readme-renderer, pytz-deprecation-shim, pydeck, markdown-it-py, jaraco.classes, gitdb, deprecation, click, tzlocal, rich, python-gitlab, keyring, httpcore, gitpython, click-log, twine, httpx, altair, supafunc, streamlit, storage3, python-semantic-release, postgrest-py, gotrue, supabase
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed altair-5.0.1 backports.zoneinfo-0.2.1 blinker-1.6.3 cachetools-5.5.2 click-8.1.8 click-log-0.4.0 dataclasses-0.6 deprecation-2.1.0 docutils-0.20.1 dotty-dict-1.3.1 gitdb-4.0.12 gitpython-3.1.50 gotrue-0.5.4 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 invoke-1.7.3 jaraco.classes-3.2.3 keyring-24.1.1 markdown-it-py-2.2.0 mdurl-0.1.2 more-itertools-9.1.0 packaging-23.2 pkginfo-1.10.0 postgrest-py-0.10.4 pyarrow-12.0.1 pydantic-1.10.26 pydeck-0.8.1b1 pympler-1.1 python-gitlab-3.15.0 python-semantic-release-7.32.1 pytz-deprecation-shim-0.1.0.post0 pywin32-ctypes-0.2.3 readme-renderer-37.3 realtime-0.0.5 requests-toolbelt-1.0.0 rfc3986-1.5.0 rich-13.8.1 semver-2.13.0 smmap-5.0.3 storage3-0.3.6 streamlit-1.23.1 strenum-0.4.15 supabase-0.7.1 supafunc-0.2.2 tenacity-8.2.3 toml-0.10.2 tomlkit-0.12.5 toolz-0.12.1 twine-3.8.0 tzdata-2026.2 tzlocal-4.3.1 validators-0.20.0 watchdog-3.0.0 websockets-10.4 wheel-0.42.0

# %%
# %%writefile app.py
import streamlit as st
from supabase import create_client

# 1. Setup connection credentials
SUPABASE_URL = "https://yxdnobocoxrchfsxdyen.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Inl4ZG5vYm9jb3hyY2hmc3hkeWVuIiwicm9sZSI6ImFub24iLCJpYXQiOjE3ODIwMDU4NzcsImV4cCI6MjA5NzU4MTg3N30.U5EjJEUylm6P-k7xRmklPqZoUyp8_LBUnRByYyhnmUI"

# 2. Initialize database client
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. App Title & UI elements
st.title("🚀 Model Experiment Tracker")
st.write("Log your local training runs directly into the cloud database.")

model_name = st.text_input("Model Name", "YOLOv8-v1")
accuracy = st.number_input("Validation Accuracy (%)", min_value=0.0, max_value=100.0, value=85.0)
notes = st.text_area("Experiment Notes", "Trained on local RTX 3050.")

# 4. Action button to send data
if st.button("Save Experiment"):
    data = {
        "model_name": model_name,
        "accuracy": accuracy,
        "notes": notes
    }
    try:
        response = supabase.table("experiments").insert(data).execute()
        st.success("✨ Successfully saved to Supabase cloud!")
    except Exception as e:
        st.error(f"❌ Failed to save: {e}")

# 5. Display existing data from the cloud
st.subheader("📊 Logged History")
try:
    response = supabase.table("experiments").select("*").execute()
    for row in response.data:
        st.write(f"- **{row['model_name']}**: {row['accuracy']}% | _ {row['notes']} _")
except Exception as e:
    st.write("Add your first experiment to see history here.")
# Out:
# Writing app.py

# %%
# !streamlit run app.py --browser.gatherUsageStats false
# Out:
# ^C

# %%
# %%writefile requirements.txt
# streamlit
# supabase
# Out:
# Writing requirements.txt
